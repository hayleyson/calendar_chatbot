# %%
import calendar_utils
import json

# %%
import importlib 
importlib.reload(calendar_utils)
# Out:
# <module 'calendar_utils' from 'C:\\Users\\ksjy\\Downloads\\conv_ai-main\\conv_ai-main\\calendar_utils.py'>

# %%
from dotenv import load_dotenv
import os
import re
import datetime

load_dotenv()
# Out:
# True

# %%
# Basic ChatGPT class
import openai
from openai import OpenAI


class BasicChatGPT:
  def __init__(self, openai_api_key, max_tokens=100):
    openai.api_key = openai_api_key
    self.max_tokens = max_tokens
    self.messages = []
    self.client = OpenAI()

  def call(self):
    response = self.client.chat.completions.create(
      model="gpt-4-1106-preview",
      # model="gpt-3.5-turbo",
      response_format={ "type": "json_object" },
      messages=self.messages,
      max_tokens=self.max_tokens
    )
    return response

  def prompt(self, text):
    # Update the messages so far
    self.messages.append({
        "role": "user",
        "content": text,
    })

    # Call ChatGPT
    response = self.call()

    # Save the returned message
    message = response["choices"][0]["message"]
    self.messages.append(message)

    return message["content"]

# %%
# # Run an interactive console to chat with ChatGPT
# def run_console(chatgpt):
#     while True:
#         # Receive user input
#         prompt = input("User: ")

#         # Exit the loop if the user entered "exit"
#         if prompt == "exit":
#             break

#         # Receive and display ChatGPT response
#         response = chatgpt.prompt(prompt)
#         print("ChatGPT:", response)
#     print("The chat has ended")

# %%
# Make a ChatGPT object
basic_chatgpt = BasicChatGPT(os.environ.get("OPENAI_API_KEY"), max_tokens = 2000)

# run_console(basic_chatgpt)

# %%
# calendar service 정의하는 부분 -> credentials.json 이 경로에 있어야 하고 
# 그리고 팝업 뜨면 너가 authorize 해줘야함 그리고 너 노트북이나 데탑 로컬에서 해야 함
# https://developers.google.com/resources/api-libraries/documentation/calendar/v3/python/latest/calendar_v3.events.html#list
service = calendar_utils.get_calendar_service()

# %%
## if user asks about "today's schedule"
## first detect today
## then find what's today
## then request calendar for today's schedule

# %%
# first detect today and then find what date is today

input_text = f"""###Instruction : Please assist in optimized schedule management. As a 'Schedule Management Application', you act to suggest necessary tasks for work input by users, manage time effectively, and aid in overall productivity enhancement. The 'Schedule Management Application' performs the following roles for the "Target Task" and "Target Time" input by the user:

Create the required subtasks for the 'Target Task'. Distribute the required subtasks for the 'Target Task' appropriately by 'Target Time'. Finally, the assistant outputs the distribution of detailed tasks by 'Target Time' in JSON format.

Restrictions: 
1. Between 00:00:00 and 09:00:00 in Asia/Seoul time is sleep time and is excluded from schedule distribution. 
2. Asia/Seoul time between 12:00:00 and 13:00:00 is lunch time and is excluded from the schedule distribution. 
3. The period between 18:00:00 and 20:00:00 in Asia/Seoul time is dinner time and is excluded from the schedule distribution.
4. Assistant only outputs JSON.

Considerations: 
1. You must consider the entire duration of the given schedule and distribute tasks so that they are not concentrated on specific days. Be sure to not concentrate your work on a specific day or time. 
2. The time allotted for a single detailed tasks must be no more than 3 hours.

Here is an example
User Input:
Today is November 21, 2023.
Target Task: I need to select and present a paper on deep learning.
Target Time: Next Monday.
Maximum number of detailed task : 5

Assistant Output(Should be JSON format):
{{
  "summery": "Selecting a Paper",
  "start": {{
  'dateTime': "2023-11-21T09:00:00+09:00",
  "timeZone": 'Asia/Seoul'
  }}
  ,
  "end": {{
  'dateTime': "2023-11-21T12:00:00+09:00",
  "timeZone": 'Asia/Seoul'
  }}
}},
{{
  "summary": "Thoroughly Reading the Paper",
  "start": {{
    "dateTime": "2023-11-21T13:00:00+09:00",
    "timeZone": "Asia/Seoul"
  }},
  "end": {{
    "dateTime": "2023-11-22T17:00:00+09:00",
    "timeZone": "Asia/Seoul"
  }}
}},
{{
  "summary": "Researching Background Information",
  "start": {{
    "dateTime": "2023-11-23T09:00:00+09:00",
    "timeZone": "Asia/Seoul"
  }},
  "end": {{
    "dateTime": "2023-11-23T12:00:00+09:00",
    "timeZone": "Asia/Seoul"
  }}
}},
{{
  "summary": "Creating the Presentation",
  "start": {{
    "dateTime": "2023-11-23T13:00:00+09:00",
    "timeZone": "Asia/Seoul"
  }},
  "end": {{
    "dateTime": "2023-11-24T17:00:00+09:00",
    "timeZone": "Asia/Seoul"
  }}
}},
{{
  "summary": "Rehearsing the Presentation",
  "start": {{
    "dateTime": "2023-11-25T09:00:00+09:00",
    "timeZone": "Asia/Seoul"
  }},
  "end": {{
    "dateTime": "2023-11-26T17:00:00+09:00",
    "timeZone": "Asia/Seoul"
  }}
}}

###User Input:
"""

input_text += """Today is November 21, 2023.
Target Task: You must perform C++ optimization assignments in computer classes and prepare for presentations.
Target Time: Next Wednesday.
Maximum number of detailed task : 3"""


basic_chatgpt.messages.append({
    "role": "user",
    "content": input_text,
})

# Call ChatGPT
response = basic_chatgpt.call()
message = response.choices[0].message.content
init_result = json.loads(message)

print(message)
# Save the returned message
# message = response["choices"][0]["message"]
# self.messages.append(message)
# Out:
# {
#   "summary": "Understand C++ Assignment Requirements",
#   "start": {
#     "dateTime": "2023-11-22T09:00:00+09:00",
#     "timeZone": "Asia/Seoul"
#   },
#   "end": {
#     "dateTime": "2023-11-22T12:00:00+09:00",
#     "timeZone": "Asia/Seoul"
#   }
# }

# %%
# mydate = datetime.datetime.strptime(init_result['date'], "%Y/%m/%d").isoformat() + "Z"
# mydate_p1 = (datetime.datetime.strptime(init_result['date'], "%Y/%m/%d") + datetime.timedelta(days=1)).isoformat() + "Z"
mydate = datetime.datetime.now(datetime.UTC).isoformat().split('+')[0] + "Z"
mydate_p1 = (datetime.datetime.now(datetime.UTC) + datetime.timedelta(days=1)).isoformat().split('+')[0] + "Z"
print(mydate)
print(mydate_p1)
# Out:
# 2023-11-21T12:27:31.941471Z
# 2023-11-22T12:27:31.941471Z

# %%
#https://developers.google.com/resources/api-libraries/documentation/calendar/v3/python/latest/calendar_v3.events.html#list

calendar_utils.get_event_list_recent(timeMin=mydate, timeMax=mydate_p1)
# Out:
# 2023-09-04T11:00:00+09:00 컴퓨팅 2
# 2023-09-04T14:00:00+09:00 MLDL2
# 2023-09-06T09:00:00+09:00 세미나
# 2023-11-15T20:00:00+09:00 대화형 자연어 처리 미팅
# 2023-11-22T12:30:00+09:00 수학 통계
# 2023-09-25T12:30:00+09:00 수학 통계
# 2023-11-22T17:00:00+09:00 기승 미팅
# [{'kind': 'calendar#event',
#   'etag': '"3387466391168000"',
#   'id': '70r62or170q3cbb371hj0b9k6cq3cb9pcpi6cbb26cs38d316lgj4dhh70',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NzByNjJvcjE3MHEzY2JiMzcxaGowYjlrNmNxM2NiOXBjcGk2Y2JiMjZjczM4ZDMxNmxnajRkaGg3MF8yMDIzMDkwNFQwMjAwMDBaIGtrc2twQHNudS5hYy5rcg',
#   'created': '2023-09-03T09:26:35.000Z',
#   'updated': '2023-09-03T09:26:35.584Z',
#   'summary': '컴퓨팅 2',
#   'creator': {'email': 'kkskp@snu.ac.kr', 'self': True},
#   'organizer': {'email': 'kkskp@snu.ac.kr', 'self': True},
#   'start': {'dateTime': '2023-09-04T11:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'end': {'dateTime': '2023-09-04T12:15:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'recurrence': ['RRULE:FREQ=WEEKLY;WKST=SU;UNTIL=20231215T145959Z;INTERVAL=1;BYDAY=MO,WE'],
#   'iCalUID': '70r62or170q3cbb371hj0b9k6cq3cb9pcpi6cbb26cs38d316lgj4dhh70@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 10}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3387466556180000"',
#   'id': '60p38c1n6csjab9n6ti3cb9k6cojcbb164om4b9k71i3adr66gs34e1n74',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NjBwMzhjMW42Y3NqYWI5bjZ0aTNjYjlrNmNvamNiYjE2NG9tNGI5azcxaTNhZHI2NmdzMzRlMW43NF8yMDIzMDkwNFQwNTAwMDBaIGtrc2twQHNudS5hYy5rcg',
#   'created': '2023-09-03T09:27:58.000Z',
#   'updated': '2023-09-03T09:27:58.090Z',
#   'summary': 'MLDL2',
#   'creator': {'email': 'kkskp@snu.ac.kr', 'self': True},
#   'organizer': {'email': 'kkskp@snu.ac.kr', 'self': True},
#   'start': {'dateTime': '2023-09-04T14:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'end': {'dateTime': '2023-09-04T15:15:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'recurrence': ['RRULE:FREQ=WEEKLY;WKST=SU;UNTIL=20231215T145959Z;INTERVAL=1;BYDAY=MO,WE'],
#   'iCalUID': '60p38c1n6csjab9n6ti3cb9k6cojcbb164om4b9k71i3adr66gs34e1n74@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 10}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3387466902928000"',
#   'id': '74smcpho61gjib9nchgjib9k6pij2b9pc8qm8bb1c8o32c9o6sr30e9k70',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NzRzbWNwaG82MWdqaWI5bmNoZ2ppYjlrNnBpajJiOXBjOHFtOGJiMWM4bzMyYzlvNnNyMzBlOWs3MF8yMDIzMDkwNlQwMDAwMDBaIGtrc2twQHNudS5hYy5rcg',
#   'created': '2023-09-03T09:30:51.000Z',
#   'updated': '2023-09-03T09:30:51.464Z',
#   'summary': '세미나',
#   'creator': {'email': 'kkskp@snu.ac.kr', 'self': True},
#   'organizer': {'email': 'kkskp@snu.ac.kr', 'self': True},
#   'start': {'dateTime': '2023-09-06T09:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'end': {'dateTime': '2023-09-06T10:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'recurrence': ['RRULE:FREQ=WEEKLY;WKST=SU;UNTIL=20231215T145959Z;INTERVAL=1;BYDAY=WE'],
#   'iCalUID': '74smcpho61gjib9nchgjib9k6pij2b9pc8qm8bb1c8o32c9o6sr30e9k70@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 10}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3390398458756000"',
#   'id': '5urt32hdt75mqhoaplsfuahn2r',
#   'status': 'cancelled'},
#  {'kind': 'calendar#event',
#   'etag': '"3399678388666000"',
#   'id': 'pl76sq8422ae5llk9sgjhnmg8c',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cGw3NnNxODQyMmFlNWxsazlzZ2pobm1nOGNfMjAyMzExMTVUMTEwMDAwWiBra3NrcEBzbnUuYWMua3I',
#   'created': '2023-11-07T02:39:08.000Z',
#   'updated': '2023-11-13T01:33:14.333Z',
#   'summary': '대화형 자연어 처리 미팅',
#   'description': '손혜령(Hye Ryung Son)이(가) 예약된 Zoom 회의에 귀하를 초대합니다.\n\n참가 Zoom 회의\nhttps://snu-ac-kr.zoom.us/j/91503616855\n\n회의 ID: 915 0361 6855\n\n---\n\n원탭 모바일\n+82231439612,,91503616855# 대한민국\n+82231439611,,91503616855# 대한민국\n\n---\n\n위치에 따라 전화 걸기\n• +82 2 3143 9612 대한민국\n• +82 2 3143 9611 대한민국\n\n회의 ID: 915 0361 6855\n\n현지 번호 찾기: https://snu-ac-kr.zoom.us/u/aeapn7vted\n\n',
#   'location': 'https://snu-ac-kr.zoom.us/j/91503616855',
#   'creator': {'email': 'hyeryung.son@snu.ac.kr'},
#   'organizer': {'email': 'hyeryung.son@snu.ac.kr'},
#   'start': {'dateTime': '2023-11-15T20:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'end': {'dateTime': '2023-11-15T21:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'recurrence': ['RRULE:FREQ=WEEKLY;WKST=SU;UNTIL=20231206T120000Z;INTERVAL=1;BYDAY=WE'],
#   'iCalUID': 'pl76sq8422ae5llk9sgjhnmg8c@google.com',
#   'sequence': 0,
#   'attendees': [{'email': 'hyeongoon11@snu.ac.kr',
#     'responseStatus': 'needsAction'},
#    {'email': 'hyeryung.son@snu.ac.kr',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'kkskp@snu.ac.kr', 'self': True, 'responseStatus': 'needsAction'},
#    {'email': 'luke0112@snu.ac.kr', 'responseStatus': 'needsAction'}],
#   'extendedProperties': {'shared': {'zmMeetingNum': '91503616855'}},
#   'guestsCanModify': True,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3400038233340000"',
#   'id': '5urt32hdt75mqhoaplsfuahn2r_20231122T033000Z',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NXVydDMyaGR0NzVtcWhvYXBsc2Z1YWhuMnJfMjAyMzExMjJUMDMzMDAwWiBra3NrcEBzbnUuYWMua3I',
#   'created': '2023-08-03T07:30:44.000Z',
#   'updated': '2023-11-15T03:31:56.670Z',
#   'summary': '수학 통계',
#   'description': '43-2동, B102',
#   'creator': {'email': 'lee.jayyoon@snu.ac.kr'},
#   'organizer': {'email': 'lee.jayyoon@snu.ac.kr'},
#   'start': {'dateTime': '2023-11-22T12:30:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'end': {'dateTime': '2023-11-22T13:45:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'recurringEventId': '5urt32hdt75mqhoaplsfuahn2r_R20230925T033000',
#   'originalStartTime': {'dateTime': '2023-11-22T12:30:00+09:00',
#    'timeZone': 'Asia/Seoul'},
#   'iCalUID': '5urt32hdt75mqhoaplsfuahn2r_R20230925T033000@google.com',
#   'sequence': 1,
#   'attendees': [{'email': 'anmh9161@snu.ac.kr', 'responseStatus': 'accepted'},
#    {'email': 'gkswns0531@snu.ac.kr', 'responseStatus': 'accepted'},
#    {'email': 'iorad@snu.ac.kr', 'responseStatus': 'accepted'},
#    {'email': 'jyj0729@snu.ac.kr', 'responseStatus': 'accepted'},
#    {'email': 'kkskp@snu.ac.kr', 'self': True, 'responseStatus': 'needsAction'},
#    {'email': 'lee.jayyoon@snu.ac.kr',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'luke0112@snu.ac.kr', 'responseStatus': 'needsAction'}],
#   'hangoutLink': 'https://meet.google.com/voq-kpgt-zsv',
#   'conferenceData': {'entryPoints': [{'entryPointType': 'video',
#      'uri': 'https://meet.google.com/voq-kpgt-zsv',
#      'label': 'meet.google.com/voq-kpgt-zsv'},
#     {'entryPointType': 'more',
#      'uri': 'https://tel.meet/voq-kpgt-zsv?pin=9150356258266',
#      'pin': '9150356258266'},
#     {'regionCode': 'US',
#      'entryPointType': 'phone',
#      'uri': 'tel:+1-470-241-4308',
#      'label': '+1 470-241-4308',
#      'pin': '735634142'}],
#    'conferenceSolution': {'key': {'type': 'hangoutsMeet'},
#     'name': 'Google Meet',
#     'iconUri': 'https://fonts.gstatic.com/s/i/productlogos/meet_2020q4/v6/web-512dp/logo_meet_2020q4_color_2x_web_512dp.png'},
#    'conferenceId': 'voq-kpgt-zsv'},
#   'guestsCanModify': True,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3400038233340000"',
#   'id': '5urt32hdt75mqhoaplsfuahn2r_R20230925T033000',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NXVydDMyaGR0NzVtcWhvYXBsc2Z1YWhuMnJfMjAyMzA5MjVUMDMzMDAwWiBra3NrcEBzbnUuYWMua3I',
#   'created': '2023-08-03T07:30:44.000Z',
#   'updated': '2023-11-15T03:31:56.670Z',
#   'summary': '수학 통계',
#   'description': '43-2동, B102',
#   'creator': {'email': 'lee.jayyoon@snu.ac.kr'},
#   'organizer': {'email': 'lee.jayyoon@snu.ac.kr'},
#   'start': {'dateTime': '2023-09-25T12:30:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'end': {'dateTime': '2023-09-25T13:45:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'recurrence': ['RRULE:FREQ=WEEKLY;WKST=SU;UNTIL=20231215T145959Z;BYDAY=MO,WE'],
#   'iCalUID': '5urt32hdt75mqhoaplsfuahn2r_R20230925T033000@google.com',
#   'sequence': 1,
#   'attendees': [{'email': 'anmh9161@snu.ac.kr', 'responseStatus': 'accepted'},
#    {'email': 'gkswns0531@snu.ac.kr', 'responseStatus': 'accepted'},
#    {'email': 'iorad@snu.ac.kr', 'responseStatus': 'needsAction'},
#    {'email': 'jyj0729@snu.ac.kr', 'responseStatus': 'accepted'},
#    {'email': 'kkskp@snu.ac.kr', 'self': True, 'responseStatus': 'needsAction'},
#    {'email': 'lee.jayyoon@snu.ac.kr',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'luke0112@snu.ac.kr', 'responseStatus': 'needsAction'}],
#   'hangoutLink': 'https://meet.google.com/voq-kpgt-zsv',
#   'conferenceData': {'entryPoints': [{'entryPointType': 'video',
#      'uri': 'https://meet.google.com/voq-kpgt-zsv',
#      'label': 'meet.google.com/voq-kpgt-zsv'},
#     {'entryPointType': 'more',
#      'uri': 'https://tel.meet/voq-kpgt-zsv?pin=9150356258266',
#      'pin': '9150356258266'},
#     {'regionCode': 'US',
#      'entryPointType': 'phone',
#      'uri': 'tel:+1-470-241-4308',
#      'label': '+1 470-241-4308',
#      'pin': '735634142'}],
#    'conferenceSolution': {'key': {'type': 'hangoutsMeet'},
#     'name': 'Google Meet',
#     'iconUri': 'https://fonts.gstatic.com/s/i/productlogos/meet_2020q4/v6/web-512dp/logo_meet_2020q4_color_2x_web_512dp.png'},
#    'conferenceId': 'voq-kpgt-zsv'},
#   'guestsCanModify': True,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3401045897528000"',
#   'id': 't3rlu2rr94c5ls7cer6ddia25t_20231121T020000Z',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=dDNybHUycnI5NGM1bHM3Y2VyNmRkaWEyNXRfMjAyMzExMjFUMDIwMDAwWiBra3NrcEBzbnUuYWMua3I',
#   'created': '2023-09-03T09:39:01.000Z',
#   'updated': '2023-11-20T23:29:08.764Z',
#   'summary': '기승 미팅',
#   'creator': {'email': 'lee.jayyoon@snu.ac.kr'},
#   'organizer': {'email': 'lee.jayyoon@snu.ac.kr'},
#   'start': {'dateTime': '2023-11-22T17:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'end': {'dateTime': '2023-11-22T17:45:00+09:00', 'timeZone': 'Asia/Seoul'},
#   'recurringEventId': 't3rlu2rr94c5ls7cer6ddia25t',
#   'originalStartTime': {'dateTime': '2023-11-21T11:00:00+09:00',
#    'timeZone': 'Asia/Seoul'},
#   'iCalUID': 't3rlu2rr94c5ls7cer6ddia25t@google.com',
#   'sequence': 7,
#   'attendees': [{'email': 'kkskp@snu.ac.kr',
#     'self': True,
#     'responseStatus': 'accepted'},
#    {'email': 'lee.jayyoon@snu.ac.kr',
#     'organizer': True,
#     'responseStatus': 'accepted'}],
#   'hangoutLink': 'https://meet.google.com/xhr-qbav-rmn',
#   'conferenceData': {'entryPoints': [{'entryPointType': 'video',
#      'uri': 'https://meet.google.com/xhr-qbav-rmn',
#      'label': 'meet.google.com/xhr-qbav-rmn'},
#     {'entryPointType': 'more',
#      'uri': 'https://tel.meet/xhr-qbav-rmn?pin=3794626448855',
#      'pin': '3794626448855'},
#     {'regionCode': 'US',
#      'entryPointType': 'phone',
#      'uri': 'tel:+1-305-912-6051',
#      'label': '+1 305-912-6051',
#      'pin': '770784694'}],
#    'conferenceSolution': {'key': {'type': 'hangoutsMeet'},
#     'name': 'Google Meet',
#     'iconUri': 'https://fonts.gstatic.com/s/i/productlogos/meet_2020q4/v6/web-512dp/logo_meet_2020q4_color_2x_web_512dp.png'},
#    'conferenceId': 'xhr-qbav-rmn'},
#   'guestsCanModify': True,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'}]

# %%
# 이거 내가 룰로 짜서 this monday -> 2023/11/27 이렇게 파싱하려고 했던 흔적임. 근데 그냥 chatgpt gpt4 한테 물어봤는데 잘해서 그냥 이거로 안했음..
# 그렇게 할 때의 input_text 는 이거였음 아래 참고

# input_text = """
# Detect any time-related word from the given input from the user.
# Examples include today, tomorrow, this Wednesday, next Tuesday, last Friday, 11/13, November 5th, 13th of July.
# When the detected word is day of week, make sure to include adjective in front of it such as "this", "next", "upcoming", "last", "past".
# \n\n
# Example 1
# Input: I want to schedule a meeting at 5PM tomorrow.
# Output: tomorrow

# Example 2
# Input: What time does the class start next Friday?
# Output: next Friday

# Example 3
# Input: What is the date of this upcoming Friday?
# Output: this upcoming Friday
# \n\nInput: 
# """


# query_date = None
# found_time_related_phrase = 'this Monday'
# found_time_related_phrase = found_time_related_phrase.lower()
# if found_time_related_phrase == 'today':
#     query_date = datetime.datetime.today().date()
# elif found_time_related_phrase == 'tomorrow':
#     query_date = datetime.datetime.today().date() + datetime.timedelta(days=1)
# elif found_time_related_phrase == 'yesterday':
#     query_date = datetime.datetime.today().date() - datetime.timedelta(days=1)
# elif 'day' in found_time_related_phrase:
#     phrases = found_time_related_phrase.split()
#     prefix = phrases[0]
#     dow = phrases[-1]
#     dow2num={'monday':0, 'tuesday':1, 'wednesday':2, 'thursday':3, 'friday': 4, 'saturday':5, 'sunday':6}
#     today = datetime.date.today()
#     this_dow = today + datetime.timedelta( (dow2num[dow]-today.weekday()) % 7 )
#     if prefix == 'this': # dow closest from today in the future
#         query_date = this_dow
#     elif prefix == 'next': # dow one week from this dow
#         query_date = this_dow + datetime.timedelta(7)
#     elif prefix == 'last': # dow one week prior to this dow
#         query_date = this_dow - datetime.timedelta(7)
# print(query_date)
# Out:
# 2023-11-27
